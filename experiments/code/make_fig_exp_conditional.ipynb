# %%
import numpy as np

from utils import *
from generate_data import * 

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import copy

from network import *

from plot_data import *
from data_loading import *

import json

from approaches.gaussian_predictor_levelsets import *
from approaches.gaussian_trainer import *

seed_everything(42)

# %%
seed_everything(42)

class RadiusTransformation2:
    def __init__(self, d, beta=None):
        if beta is None:
            beta = np.random.randn(d)
        self.beta = beta

    def get(self, x):
        return ((( np.linalg.norm(x)) / 2.0 + (np.dot(self.beta, x))**2 / 10) / 2 ) / .5 + 0.15

d = 2
hidden_dim = 5
hidden_dim_matrix = 100
k = 2

input_dim = d
output_dim = k

tab_coverage = []
tab_warm_start_covariance_coverage = []
tab_warm_start_local_covariance_coverage = []
tab_hyper_rectangle_coverage = []

pert = "exponential"

n_train = 20_000
n_test = 1_000
n_calibration = 1_000
n_stop = 1_000
n_anchors = 10

config_name = "exp_t"

config_path = "../parameters/" + config_name + ".json"

with open(config_path, 'r') as file : 
    parameters = json.load(file)

hidden_dim = parameters["hidden_dim"]
hidden_dim_matrix = parameters["hidden_dim_matrix"]
n_hidden_layers = parameters["n_hidden_layers"]
n_hidden_layers_matrix = parameters["n_hidden_layers_matrix"]


num_epochs = parameters["num_epochs"]

lr_matrix = parameters["lr_matrix"]

batch_size = parameters["batch_size"]

idx_knowned = np.array(parameters["idx_knowned"])

dtype = torch.float32 if parameters["dtype"] == "float32" else torch.float64

alpha = 0.1

class NonLinearFunction2:
    def __init__(self, d, k, beta=None):
        if beta is None:
            beta = np.random.randn(d, k)
        self.beta = beta
        self.proj  = np.zeros((d, k))
        self.proj[0, 0] = 1.0
        self.proj[1, 1] = 1.0

    def get(self, x):
        nonlinear_term = np.sin(np.dot(x, self.beta)) + 0.5 * np.tanh(np.dot(x**2, self.beta)) + np.dot(x, self.proj)
        return nonlinear_term * 2

f_star = NonLinearFunction2(d, k)
radius = RadiusTransformation2(d)
local_perturbation = LocalPerturbation(d, k, n_anchors=n_anchors, radius_transformation=radius)
data_generator = DataGenerator(d, k, pert, f_star=f_star, local_perturbation=local_perturbation, covariance_matrix=np.array([[1.0, 0.5],[0.5, 1.0]]), bias = False, seed = 42)

x_train, y_train = data_generator.generate(n_train)
x_stop, y_stop = data_generator.generate(n_stop)
x_calibration, y_calibration = data_generator.generate(n_calibration)
x_test, y_test = data_generator.generate(n_test)


x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
x_stop_tensor = torch.tensor(x_stop, dtype=torch.float32)
y_stop_tensor = torch.tensor(y_stop, dtype=torch.float32)
x_calibration_tensor = torch.tensor(x_calibration, dtype=torch.float32)
y_calibration_tensor = torch.tensor(y_calibration, dtype=torch.float32)
x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

trainloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_tensor, y_train_tensor), batch_size= batch_size, shuffle=True)
stoploader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_stop_tensor, y_stop_tensor), batch_size= batch_size, shuffle=True)
calibrationloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_calibration_tensor, y_calibration_tensor), batch_size= batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_tensor, y_test_tensor), batch_size= batch_size, shuffle=True)

# %%
trainloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_tensor, y_train_tensor), batch_size= batch_size, shuffle=True)
stoploader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_stop_tensor, y_stop_tensor), batch_size= batch_size, shuffle=True)
calibrationloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_calibration_tensor, y_calibration_tensor), batch_size= batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_tensor, y_test_tensor), batch_size= batch_size, shuffle=True)

# %%
seed_everything(42)

hidden_dim = 128
num_layers = 3
batch_size = 32
num_epochs = 300
lr = 1e-3

trainloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_tensor, y_train_tensor), batch_size= batch_size, shuffle=True)
stoploader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_stop_tensor, y_stop_tensor), batch_size= batch_size, shuffle=True)

gaussian_trainer = GaussianTrainer(input_dim, 
                            output_dim,
                            hidden_dim = hidden_dim,
                            num_layers = num_layers
                            )

gaussian_trainer.fit(trainloader, 
                    stoploader,
                    num_epochs=num_epochs,
                    lr=lr,
                    verbose = 2
                    )

center_model = gaussian_trainer.center_model
matrix_model = gaussian_trainer.matrix_model

gaussian_level_sets = GaussianPredictorLevelsets(center_model, matrix_model, dtype=dtype)
# Out:
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/approaches/gaussian_trainer.py:112: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2259.)
#   z = torch.triangular_solve(diff, L, upper=False)[0]
# Epoch 1: Avg NLL Loss = 0.8090 -- Stop loss: 0.4191 -- Best Stop Loss: inf
# Epoch 2: Avg NLL Loss = 0.5437 -- Stop loss: 0.4965 -- Best Stop Loss: 0.4190719414036721
# Epoch 3: Avg NLL Loss = 0.5014 -- Stop loss: 0.5002 -- Best Stop Loss: 0.4190719414036721
# Epoch 4: Avg NLL Loss = 0.4862 -- Stop loss: 0.3664 -- Best Stop Loss: 0.4190719414036721
# Epoch 5: Avg NLL Loss = 0.4705 -- Stop loss: 0.3596 -- Best Stop Loss: 0.3664152016863227
# Epoch 6: Avg NLL Loss = 0.4587 -- Stop loss: 0.3342 -- Best Stop Loss: 0.3595520802773535
# Epoch 7: Avg NLL Loss = 0.4661 -- Stop loss: 0.3455 -- Best Stop Loss: 0.3341538899112493
# Epoch 8: Avg NLL Loss = 0.4507 -- Stop loss: 0.3673 -- Best Stop Loss: 0.3341538899112493
# Epoch 9: Avg NLL Loss = 0.4452 -- Stop loss: 0.3770 -- Best Stop Loss: 0.3341538899112493
# Epoch 10: Avg NLL Loss = 0.4349 -- Stop loss: 0.4020 -- Best Stop Loss: 0.3341538899112493
# Epoch 11: Avg NLL Loss = 0.4321 -- Stop loss: 0.3078 -- Best Stop Loss: 0.3341538899112493
# Epoch 12: Avg NLL Loss = 0.4343 -- Stop loss: 0.3829 -- Best Stop Loss: 0.3077890262939036
# Epoch 13: Avg NLL Loss = 0.4335 -- Stop loss: 0.3336 -- Best Stop Loss: 0.3077890262939036
# Epoch 14: Avg NLL Loss = 0.4264 -- Stop loss: 0.3414 -- Best Stop Loss: 0.3077890262939036
# Epoch 15: Avg NLL Loss = 0.4317 -- Stop loss: 0.4143 -- Best Stop Loss: 0.3077890262939036
# Epoch 16: Avg NLL Loss = 0.4242 -- Stop loss: 0.3628 -- Best Stop Loss: 0.3077890262939036
# Epoch 17: Avg NLL Loss = 0.4234 -- Stop loss: 0.2944 -- Best Stop Loss: 0.3077890262939036
# Epoch 18: Avg NLL Loss = 0.4215 -- Stop loss: 0.3521 -- Best Stop Loss: 0.2944001452997327
# Epoch 19: Avg NLL Loss = 0.4149 -- Stop loss: 0.3187 -- Best Stop Loss: 0.2944001452997327
# Epoch 20: Avg NLL Loss = 0.4175 -- Stop loss: 0.3740 -- Best Stop Loss: 0.2944001452997327
# Epoch 21: Avg NLL Loss = 0.4197 -- Stop loss: 0.3043 -- Best Stop Loss: 0.2944001452997327
# Epoch 22: Avg NLL Loss = 0.4143 -- Stop loss: 0.3330 -- Best Stop Loss: 0.2944001452997327
# Epoch 23: Avg NLL Loss = 0.4127 -- Stop loss: 0.3315 -- Best Stop Loss: 0.2944001452997327
# Epoch 24: Avg NLL Loss = 0.4122 -- Stop loss: 0.3218 -- Best Stop Loss: 0.2944001452997327
# Epoch 25: Avg NLL Loss = 0.4098 -- Stop loss: 0.3850 -- Best Stop Loss: 0.2944001452997327
# Epoch 26: Avg NLL Loss = 0.4061 -- Stop loss: 0.2899 -- Best Stop Loss: 0.2944001452997327
# Epoch 27: Avg NLL Loss = 0.4055 -- Stop loss: 0.3770 -- Best Stop Loss: 0.2899121363880113
# Epoch 28: Avg NLL Loss = 0.4045 -- Stop loss: 0.3296 -- Best Stop Loss: 0.2899121363880113
# Epoch 29: Avg NLL Loss = 0.4021 -- Stop loss: 0.3772 -- Best Stop Loss: 0.2899121363880113
# Epoch 30: Avg NLL Loss = 0.4024 -- Stop loss: 0.3401 -- Best Stop Loss: 0.2899121363880113
# Epoch 31: Avg NLL Loss = 0.4013 -- Stop loss: 0.3483 -- Best Stop Loss: 0.2899121363880113
# Epoch 32: Avg NLL Loss = 0.4042 -- Stop loss: 0.3570 -- Best Stop Loss: 0.2899121363880113
# Epoch 33: Avg NLL Loss = 0.4029 -- Stop loss: 0.3710 -- Best Stop Loss: 0.2899121363880113
# Epoch 34: Avg NLL Loss = 0.4044 -- Stop loss: 0.3204 -- Best Stop Loss: 0.2899121363880113
# Epoch 35: Avg NLL Loss = 0.3985 -- Stop loss: 0.3560 -- Best Stop Loss: 0.2899121363880113
# Epoch 36: Avg NLL Loss = 0.4002 -- Stop loss: 0.3547 -- Best Stop Loss: 0.2899121363880113
# Epoch 37: Avg NLL Loss = 0.3985 -- Stop loss: 0.3598 -- Best Stop Loss: 0.2899121363880113
# Epoch 38: Avg NLL Loss = 0.3938 -- Stop loss: 0.3081 -- Best Stop Loss: 0.2899121363880113
# Epoch 39: Avg NLL Loss = 0.3988 -- Stop loss: 0.3365 -- Best Stop Loss: 0.2899121363880113
# Epoch 40: Avg NLL Loss = 0.3952 -- Stop loss: 0.3461 -- Best Stop Loss: 0.2899121363880113
# Epoch 41: Avg NLL Loss = 0.3997 -- Stop loss: 0.2998 -- Best Stop Loss: 0.2899121363880113
# Epoch 42: Avg NLL Loss = 0.3967 -- Stop loss: 0.3289 -- Best Stop Loss: 0.2899121363880113
# Epoch 43: Avg NLL Loss = 0.3989 -- Stop loss: 0.3233 -- Best Stop Loss: 0.2899121363880113
# Epoch 44: Avg NLL Loss = 0.3900 -- Stop loss: 0.3301 -- Best Stop Loss: 0.2899121363880113
# Epoch 45: Avg NLL Loss = 0.3898 -- Stop loss: 0.2901 -- Best Stop Loss: 0.2899121363880113
# Epoch 46: Avg NLL Loss = 0.3932 -- Stop loss: 0.3015 -- Best Stop Loss: 0.2899121363880113
# Epoch 47: Avg NLL Loss = 0.3979 -- Stop loss: 0.3285 -- Best Stop Loss: 0.2899121363880113
# Epoch 48: Avg NLL Loss = 0.3934 -- Stop loss: 0.3242 -- Best Stop Loss: 0.2899121363880113
# Epoch 49: Avg NLL Loss = 0.3923 -- Stop loss: 0.3463 -- Best Stop Loss: 0.2899121363880113
# Epoch 50: Avg NLL Loss = 0.3926 -- Stop loss: 0.3679 -- Best Stop Loss: 0.2899121363880113
# Epoch 51: Avg NLL Loss = 0.3944 -- Stop loss: 0.3133 -- Best Stop Loss: 0.2899121363880113
# Epoch 52: Avg NLL Loss = 0.3906 -- Stop loss: 0.2948 -- Best Stop Loss: 0.2899121363880113
# Epoch 53: Avg NLL Loss = 0.3903 -- Stop loss: 0.3245 -- Best Stop Loss: 0.2899121363880113
# Epoch 54: Avg NLL Loss = 0.3903 -- Stop loss: 0.2998 -- Best Stop Loss: 0.2899121363880113
# Epoch 55: Avg NLL Loss = 0.3874 -- Stop loss: 0.3517 -- Best Stop Loss: 0.2899121363880113
# Epoch 56: Avg NLL Loss = 0.3970 -- Stop loss: 0.3383 -- Best Stop Loss: 0.2899121363880113
# Epoch 57: Avg NLL Loss = 0.3874 -- Stop loss: 0.3064 -- Best Stop Loss: 0.2899121363880113
# Epoch 58: Avg NLL Loss = 0.3903 -- Stop loss: 0.3065 -- Best Stop Loss: 0.2899121363880113
# Epoch 59: Avg NLL Loss = 0.3847 -- Stop loss: 0.4005 -- Best Stop Loss: 0.2899121363880113
# Epoch 60: Avg NLL Loss = 0.3866 -- Stop loss: 0.3080 -- Best Stop Loss: 0.2899121363880113
# Epoch 61: Avg NLL Loss = 0.3831 -- Stop loss: 0.3316 -- Best Stop Loss: 0.2899121363880113
# Epoch 62: Avg NLL Loss = 0.3840 -- Stop loss: 0.3141 -- Best Stop Loss: 0.2899121363880113
# Epoch 63: Avg NLL Loss = 0.3820 -- Stop loss: 0.3214 -- Best Stop Loss: 0.2899121363880113
# Epoch 64: Avg NLL Loss = 0.3861 -- Stop loss: 0.3433 -- Best Stop Loss: 0.2899121363880113
# Epoch 65: Avg NLL Loss = 0.3865 -- Stop loss: 0.2974 -- Best Stop Loss: 0.2899121363880113
# Epoch 66: Avg NLL Loss = 0.3877 -- Stop loss: 0.2807 -- Best Stop Loss: 0.2899121363880113
# Epoch 67: Avg NLL Loss = 0.3900 -- Stop loss: 0.3401 -- Best Stop Loss: 0.2807465570513159
# Epoch 68: Avg NLL Loss = 0.3893 -- Stop loss: 0.3562 -- Best Stop Loss: 0.2807465570513159
# Epoch 196: Avg NLL Loss = 0.3668 -- Stop loss: 0.3420 -- Best Stop Loss: 0.27720416500233114
# Epoch 197: Avg NLL Loss = 0.3709 -- Stop loss: 0.3488 -- Best Stop Loss: 0.27720416500233114
# Epoch 198: Avg NLL Loss = 0.3629 -- Stop loss: 0.2946 -- Best Stop Loss: 0.27720416500233114
# Epoch 199: Avg NLL Loss = 0.3623 -- Stop loss: 0.2928 -- Best Stop Loss: 0.27720416500233114
# Epoch 200: Avg NLL Loss = 0.3639 -- Stop loss: 0.2981 -- Best Stop Loss: 0.27720416500233114
# Epoch 201: Avg NLL Loss = 0.3651 -- Stop loss: 0.3155 -- Best Stop Loss: 0.27720416500233114
# Epoch 202: Avg NLL Loss = 0.3672 -- Stop loss: 0.2709 -- Best Stop Loss: 0.27720416500233114
# Epoch 203: Avg NLL Loss = 0.3665 -- Stop loss: 0.2799 -- Best Stop Loss: 0.270888845436275
# Epoch 204: Avg NLL Loss = 0.3665 -- Stop loss: 0.2877 -- Best Stop Loss: 0.270888845436275
# Epoch 205: Avg NLL Loss = 0.3642 -- Stop loss: 0.2805 -- Best Stop Loss: 0.270888845436275
# Epoch 206: Avg NLL Loss = 0.3660 -- Stop loss: 0.3040 -- Best Stop Loss: 0.270888845436275
# Epoch 207: Avg NLL Loss = 0.3621 -- Stop loss: 0.3120 -- Best Stop Loss: 0.270888845436275
# Epoch 208: Avg NLL Loss = 0.3656 -- Stop loss: 0.3532 -- Best Stop Loss: 0.270888845436275
# Epoch 209: Avg NLL Loss = 0.3693 -- Stop loss: 0.2915 -- Best Stop Loss: 0.270888845436275
# Epoch 210: Avg NLL Loss = 0.3678 -- Stop loss: 0.2996 -- Best Stop Loss: 0.270888845436275
# Epoch 211: Avg NLL Loss = 0.3636 -- Stop loss: 0.3199 -- Best Stop Loss: 0.270888845436275
# Epoch 212: Avg NLL Loss = 0.3615 -- Stop loss: 0.2878 -- Best Stop Loss: 0.270888845436275
# Epoch 213: Avg NLL Loss = 0.3625 -- Stop loss: 0.3042 -- Best Stop Loss: 0.270888845436275
# Epoch 214: Avg NLL Loss = 0.3681 -- Stop loss: 0.2990 -- Best Stop Loss: 0.270888845436275
# Epoch 215: Avg NLL Loss = 0.3584 -- Stop loss: 0.3477 -- Best Stop Loss: 0.270888845436275
# Epoch 216: Avg NLL Loss = 0.3667 -- Stop loss: 0.2896 -- Best Stop Loss: 0.270888845436275
# Epoch 217: Avg NLL Loss = 0.3682 -- Stop loss: 0.2998 -- Best Stop Loss: 0.270888845436275
# Epoch 218: Avg NLL Loss = 0.3653 -- Stop loss: 0.2886 -- Best Stop Loss: 0.270888845436275
# Epoch 219: Avg NLL Loss = 0.3624 -- Stop loss: 0.2662 -- Best Stop Loss: 0.270888845436275
# Epoch 220: Avg NLL Loss = 0.3646 -- Stop loss: 0.3065 -- Best Stop Loss: 0.26616665173787624
# Epoch 221: Avg NLL Loss = 0.3685 -- Stop loss: 0.3384 -- Best Stop Loss: 0.26616665173787624
# Epoch 222: Avg NLL Loss = 0.3602 -- Stop loss: 0.3127 -- Best Stop Loss: 0.26616665173787624
# Epoch 223: Avg NLL Loss = 0.3624 -- Stop loss: 0.2714 -- Best Stop Loss: 0.26616665173787624
# Epoch 224: Avg NLL Loss = 0.3657 -- Stop loss: 0.3128 -- Best Stop Loss: 0.26616665173787624
# Epoch 225: Avg NLL Loss = 0.3635 -- Stop loss: 0.2977 -- Best Stop Loss: 0.26616665173787624
# Epoch 226: Avg NLL Loss = 0.3642 -- Stop loss: 0.2620 -- Best Stop Loss: 0.26616665173787624
# Epoch 227: Avg NLL Loss = 0.3696 -- Stop loss: 0.3213 -- Best Stop Loss: 0.2620396478450857
# Epoch 228: Avg NLL Loss = 0.3650 -- Stop loss: 0.2883 -- Best Stop Loss: 0.2620396478450857
# Epoch 229: Avg NLL Loss = 0.3627 -- Stop loss: 0.3277 -- Best Stop Loss: 0.2620396478450857
# Epoch 230: Avg NLL Loss = 0.3691 -- Stop loss: 0.3337 -- Best Stop Loss: 0.2620396478450857
# Epoch 231: Avg NLL Loss = 0.3668 -- Stop loss: 0.2870 -- Best Stop Loss: 0.2620396478450857
# Epoch 232: Avg NLL Loss = 0.3672 -- Stop loss: 0.2814 -- Best Stop Loss: 0.2620396478450857
# Epoch 233: Avg NLL Loss = 0.3666 -- Stop loss: 0.3273 -- Best Stop Loss: 0.2620396478450857
# Epoch 234: Avg NLL Loss = 0.3673 -- Stop loss: 0.2949 -- Best Stop Loss: 0.2620396478450857
# Epoch 235: Avg NLL Loss = 0.3659 -- Stop loss: 0.3143 -- Best Stop Loss: 0.2620396478450857
# Epoch 236: Avg NLL Loss = 0.3674 -- Stop loss: 0.3000 -- Best Stop Loss: 0.2620396478450857
# Epoch 237: Avg NLL Loss = 0.3642 -- Stop loss: 0.3220 -- Best Stop Loss: 0.2620396478450857
# Epoch 238: Avg NLL Loss = 0.3645 -- Stop loss: 0.3026 -- Best Stop Loss: 0.2620396478450857
# Epoch 239: Avg NLL Loss = 0.3605 -- Stop loss: 0.3071 -- Best Stop Loss: 0.2620396478450857
# Epoch 240: Avg NLL Loss = 0.3621 -- Stop loss: 0.3131 -- Best Stop Loss: 0.2620396478450857
# Epoch 241: Avg NLL Loss = 0.3668 -- Stop loss: 0.2762 -- Best Stop Loss: 0.2620396478450857
# Epoch 242: Avg NLL Loss = 0.3627 -- Stop loss: 0.2876 -- Best Stop Loss: 0.2620396478450857
# Epoch 243: Avg NLL Loss = 0.3661 -- Stop loss: 0.3023 -- Best Stop Loss: 0.2620396478450857
# Epoch 244: Avg NLL Loss = 0.3651 -- Stop loss: 0.3067 -- Best Stop Loss: 0.2620396478450857
# Epoch 245: Avg NLL Loss = 0.3636 -- Stop loss: 0.2864 -- Best Stop Loss: 0.2620396478450857
# Epoch 246: Avg NLL Loss = 0.3602 -- Stop loss: 0.3078 -- Best Stop Loss: 0.2620396478450857
# Epoch 247: Avg NLL Loss = 0.3643 -- Stop loss: 0.3624 -- Best Stop Loss: 0.2620396478450857
# Epoch 248: Avg NLL Loss = 0.3625 -- Stop loss: 0.3203 -- Best Stop Loss: 0.2620396478450857
# Epoch 249: Avg NLL Loss = 0.3638 -- Stop loss: 0.2953 -- Best Stop Loss: 0.2620396478450857
# Epoch 250: Avg NLL Loss = 0.3635 -- Stop loss: 0.2833 -- Best Stop Loss: 0.2620396478450857
# Epoch 251: Avg NLL Loss = 0.3600 -- Stop loss: 0.3326 -- Best Stop Loss: 0.2620396478450857
# Epoch 252: Avg NLL Loss = 0.3617 -- Stop loss: 0.2855 -- Best Stop Loss: 0.2620396478450857
# Epoch 253: Avg NLL Loss = 0.3597 -- Stop loss: 0.2888 -- Best Stop Loss: 0.2620396478450857
# Epoch 254: Avg NLL Loss = 0.3633 -- Stop loss: 0.3001 -- Best Stop Loss: 0.2620396478450857
# Epoch 255: Avg NLL Loss = 0.3596 -- Stop loss: 0.3075 -- Best Stop Loss: 0.2620396478450857
# Epoch 256: Avg NLL Loss = 0.3612 -- Stop loss: 0.3172 -- Best Stop Loss: 0.2620396478450857
# Epoch 257: Avg NLL Loss = 0.3614 -- Stop loss: 0.2795 -- Best Stop Loss: 0.2620396478450857
# Epoch 258: Avg NLL Loss = 0.3659 -- Stop loss: 0.3055 -- Best Stop Loss: 0.2620396478450857
# Epoch 259: Avg NLL Loss = 0.3668 -- Stop loss: 0.2975 -- Best Stop Loss: 0.2620396478450857
# Epoch 260: Avg NLL Loss = 0.3649 -- Stop loss: 0.2927 -- Best Stop Loss: 0.2620396478450857
# Epoch 261: Avg NLL Loss = 0.3678 -- Stop loss: 0.3167 -- Best Stop Loss: 0.2620396478450857
# Epoch 262: Avg NLL Loss = 0.3593 -- Stop loss: 0.2758 -- Best Stop Loss: 0.2620396478450857
# Epoch 263: Avg NLL Loss = 0.3589 -- Stop loss: 0.3106 -- Best Stop Loss: 0.2620396478450857
# Epoch 264: Avg NLL Loss = 0.3616 -- Stop loss: 0.3188 -- Best Stop Loss: 0.2620396478450857
# Epoch 265: Avg NLL Loss = 0.3632 -- Stop loss: 0.3179 -- Best Stop Loss: 0.2620396478450857
# Epoch 266: Avg NLL Loss = 0.3614 -- Stop loss: 0.3196 -- Best Stop Loss: 0.2620396478450857
# Epoch 267: Avg NLL Loss = 0.3659 -- Stop loss: 0.3330 -- Best Stop Loss: 0.2620396478450857
# Epoch 268: Avg NLL Loss = 0.3619 -- Stop loss: 0.3032 -- Best Stop Loss: 0.2620396478450857
# Epoch 269: Avg NLL Loss = 0.3627 -- Stop loss: 0.2989 -- Best Stop Loss: 0.2620396478450857
# Epoch 270: Avg NLL Loss = 0.3675 -- Stop loss: 0.3131 -- Best Stop Loss: 0.2620396478450857
# Epoch 271: Avg NLL Loss = 0.3635 -- Stop loss: 0.2958 -- Best Stop Loss: 0.2620396478450857
# Epoch 272: Avg NLL Loss = 0.3581 -- Stop loss: 0.2957 -- Best Stop Loss: 0.2620396478450857
# Epoch 273: Avg NLL Loss = 0.3620 -- Stop loss: 0.2824 -- Best Stop Loss: 0.2620396478450857
# Epoch 274: Avg NLL Loss = 0.3680 -- Stop loss: 0.2739 -- Best Stop Loss: 0.2620396478450857
# Epoch 275: Avg NLL Loss = 0.3647 -- Stop loss: 0.3251 -- Best Stop Loss: 0.2620396478450857
# Epoch 276: Avg NLL Loss = 0.3580 -- Stop loss: 0.3106 -- Best Stop Loss: 0.2620396478450857
# Epoch 277: Avg NLL Loss = 0.3630 -- Stop loss: 0.3454 -- Best Stop Loss: 0.2620396478450857
# Epoch 278: Avg NLL Loss = 0.3638 -- Stop loss: 0.3015 -- Best Stop Loss: 0.2620396478450857
# Epoch 279: Avg NLL Loss = 0.3654 -- Stop loss: 0.3025 -- Best Stop Loss: 0.2620396478450857
# Epoch 280: Avg NLL Loss = 0.3635 -- Stop loss: 0.2818 -- Best Stop Loss: 0.2620396478450857
# Epoch 281: Avg NLL Loss = 0.3614 -- Stop loss: 0.3069 -- Best Stop Loss: 0.2620396478450857
# Epoch 282: Avg NLL Loss = 0.3620 -- Stop loss: 0.3097 -- Best Stop Loss: 0.2620396478450857
# Epoch 283: Avg NLL Loss = 0.3650 -- Stop loss: 0.2838 -- Best Stop Loss: 0.2620396478450857
# Epoch 284: Avg NLL Loss = 0.3631 -- Stop loss: 0.3440 -- Best Stop Loss: 0.2620396478450857
# Epoch 285: Avg NLL Loss = 0.3619 -- Stop loss: 0.3345 -- Best Stop Loss: 0.2620396478450857
# Epoch 286: Avg NLL Loss = 0.3609 -- Stop loss: 0.3092 -- Best Stop Loss: 0.2620396478450857
# Epoch 287: Avg NLL Loss = 0.3603 -- Stop loss: 0.2890 -- Best Stop Loss: 0.2620396478450857
# Epoch 288: Avg NLL Loss = 0.3598 -- Stop loss: 0.3027 -- Best Stop Loss: 0.2620396478450857
# Epoch 289: Avg NLL Loss = 0.3684 -- Stop loss: 0.3127 -- Best Stop Loss: 0.2620396478450857
# Epoch 290: Avg NLL Loss = 0.3635 -- Stop loss: 0.3087 -- Best Stop Loss: 0.2620396478450857
# Epoch 291: Avg NLL Loss = 0.3639 -- Stop loss: 0.3119 -- Best Stop Loss: 0.2620396478450857
# Epoch 292: Avg NLL Loss = 0.3613 -- Stop loss: 0.2862 -- Best Stop Loss: 0.2620396478450857
# Epoch 293: Avg NLL Loss = 0.3611 -- Stop loss: 0.2986 -- Best Stop Loss: 0.2620396478450857
# Epoch 294: Avg NLL Loss = 0.3683 -- Stop loss: 0.3328 -- Best Stop Loss: 0.2620396478450857
# Epoch 295: Avg NLL Loss = 0.3662 -- Stop loss: 0.3085 -- Best Stop Loss: 0.2620396478450857
# Epoch 296: Avg NLL Loss = 0.3630 -- Stop loss: 0.3118 -- Best Stop Loss: 0.2620396478450857
# Epoch 297: Avg NLL Loss = 0.3608 -- Stop loss: 0.3463 -- Best Stop Loss: 0.2620396478450857
# Epoch 298: Avg NLL Loss = 0.3638 -- Stop loss: 0.2867 -- Best Stop Loss: 0.2620396478450857
# Epoch 299: Avg NLL Loss = 0.3638 -- Stop loss: 0.3152 -- Best Stop Loss: 0.2620396478450857
# Best stop loss achieved: 0.2620

# %%
gaussian_level_sets.conformalize(x_calibration=x_calibration_tensor, y_calibration=y_calibration_tensor, alpha = alpha)
# Out:
# tensor(2.0828)

# %%
idx_knowned = np.array([0])

gaussian_level_sets.conformalize_with_knowned_idx(x_calibration=x_calibration_tensor, 
                                            y_calibration=y_calibration_tensor, 
                                            alpha = alpha, 
                                            idx_knowned=idx_knowned)
# Out:
# tensor(1.3828)

# %%
from matplotlib.lines import Line2D

# %%
tab_seed = [14, 18, 19, 55]
q_val = 2.0
dtype = torch.float32

coverage_emp = []

idx_unknown = np.setdiff1d(np.arange(k), idx_knowned) 

fig, ax = plt.subplots(figsize=(6, 6))

color_map = plt.cm.get_cmap('viridis', 5)
colors = color_map(np.linspace(0, 1, 5))
darker_colors = colors.copy()
from matplotlib.colors import ListedColormap
darker_viridis = ListedColormap(darker_colors)

darker_colors[:, :3] *= 0.6
for i, seed in enumerate(tab_seed): 
        seed_everything(seed)
        x_specific, y_specific = data_generator.generate_specific_x(100)

        if seed == 14:
                y_specific[0] = np.array([1.0, 0.0])

        x_specific_tensor = torch.tensor(x_specific, dtype=dtype)
        y_specific_tensor = torch.tensor(y_specific, dtype=dtype)

        centers = gaussian_level_sets.get_centers(x_specific_tensor)
        centers_np = centers.detach().numpy()
        Lambdas_specific = gaussian_level_sets.get_Lambdas(x_specific_tensor)
        Lambdas_specific_np = Lambdas_specific.detach().numpy()

        radius = gaussian_level_sets.nu_conformal.item()

        
        ax = add_ellipse(ax,  centers_np[0], Lambdas_specific_np[0], q_val, radius, color = darker_viridis(i), linestyle='--', label=None)
          
        coverage_emp.append(gaussian_level_sets.get_coverage(x_specific_tensor, y_specific_tensor))
        
        y_values = []
        for j in range(1):
                t = y_specific_tensor[j, 0]                
                for y in np.linspace(-10, 10, 10_000):  # Plage de valeurs pour y
                        t_y = torch.tensor([t, y], dtype = dtype).unsqueeze(0)                         
                        
                        y_r = t_y[:, idx_knowned]
                        y_s = t_y[:, idx_unknown]

                        inside = gaussian_level_sets.get_coverage_condition_on_idx(x_specific_tensor[[0]] ,t_y)

                        if inside:
                                y_values.append(y)

                ax.plot([t, t], [min(y_values), max(y_values)], color=darker_viridis(i),  label=None)
                ax.plot([t-0.2, t+0.2], [min(y_values), min(y_values)], label=None, color=darker_viridis(i))
                ax.plot([t-0.2, t+0.2], [max(y_values), max(y_values)], label=None, color=darker_viridis(i))
       
        ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
        ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)

ax = add_ellipse(ax,  centers_np[0] + np.array([100, 100]), Lambdas_specific_np[0], q_val, radius, color = "black", linestyle='--', label=fr'$C_\alpha(X_{{i}})$')
ax.plot([t, t], [min(y_values)+ 100, max(y_values)+100], color="black",  label=fr'$C_\alpha(X_{{i}}, Y_{{i}}^{{R}})$')

ax.set_xlabel(r'$Y^1$', fontsize=14)
ax.set_ylabel(r'$Y^2$', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
leg = ax.legend(fontsize=14, loc='lower right', ncols=2)
ax.set_xlim(-8, 9)
ax.set_ylim(-4, 10)
leg.set_zorder(2)

ax.plot([3.25, 3.25], [-3.3, -3.0], color="black", zorder=3)
ax.plot([4.6, 4.6], [-3.3, -3.0], color="black", zorder=3)
        
plt.tight_layout()

plt.savefig(f"../figs/revealed_{pert}_level_sets_{coverage_emp[0]:.2f}_{coverage_emp[1]:.2f}_{coverage_emp[2]:.2f}_{coverage_emp[3]:.2f}.pdf", dpi = 300, bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/342477168.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/plot_data.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/342477168.py:58: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/342477168.py:59: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)

# %%
tab_seed = [14, 18, 19, 55]
q_val = 2.0
dtype = torch.float32

coverage_emp = []

idx_unknown = np.setdiff1d(np.arange(k), idx_knowned) 

fig, ax = plt.subplots(figsize=(6, 6))

color_map = plt.cm.get_cmap('viridis', 5)
colors = color_map(np.linspace(0, 1, 5))
darker_colors = colors.copy()
from matplotlib.colors import ListedColormap
darker_viridis = ListedColormap(darker_colors)

darker_colors[:, :3] *= 0.6
for i, seed in enumerate(tab_seed): 
        seed_everything(seed)
        fig, ax = plt.subplots(figsize=(6, 6))

        color_map = plt.cm.get_cmap('viridis', 5)
        colors = color_map(np.linspace(0, 1, 5))
        darker_colors = colors.copy()
        from matplotlib.colors import ListedColormap
        darker_viridis = ListedColormap(darker_colors)

        x_specific, y_specific = data_generator.generate_specific_x(100)

        if seed == 14:
                y_specific[0] = np.array([1.0, 0.0])

        x_specific_tensor = torch.tensor(x_specific, dtype=dtype)
        y_specific_tensor = torch.tensor(y_specific, dtype=dtype)

        centers = gaussian_level_sets.get_centers(x_specific_tensor)
        centers_np = centers.detach().numpy()
        Lambdas_specific = gaussian_level_sets.get_Lambdas(x_specific_tensor)
        Lambdas_specific_np = Lambdas_specific.detach().numpy()

        radius = gaussian_level_sets.nu_conformal.item()

        
        ax = add_ellipse(ax,  centers_np[0], Lambdas_specific_np[0], q_val, radius, color = darker_viridis(i), linestyle='--', label=None)
          
        coverage_emp.append(gaussian_level_sets.get_coverage(x_specific_tensor, y_specific_tensor))
        
        y_values = []
        for j in range(1):
                t = y_specific_tensor[j, 0]                
                for y in np.linspace(-10, 10, 10_000):  # Plage de valeurs pour y
                        t_y = torch.tensor([t, y], dtype = dtype).unsqueeze(0)                         
                        
                        y_r = t_y[:, idx_knowned]
                        y_s = t_y[:, idx_unknown]

                        inside = gaussian_level_sets.get_coverage_condition_on_idx(x_specific_tensor[[0]] ,t_y)

                        if inside:
                                y_values.append(y)

                ax.plot([t, t], [min(y_values), max(y_values)], color=darker_viridis(i),  label=None)
                # ax.plot([t-0.2, t+0.2], [min(y_values), min(y_values)], label=None, color=darker_viridis(i))
                # ax.plot([t-0.2, t+0.2], [max(y_values), max(y_values)], label=None, color=darker_viridis(i))

       
        ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
        ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)

        # ax = add_ellipse(ax,  centers_np[0] + np.array([100, 100]), Lambdas_specific_np[0], q_val, radius, color = "black", linestyle='--', label=fr'$C_\alpha(X_{{i}})$')
        # ax.plot([t, t], [min(y_values)+ 100, max(y_values)+100], color="black",  label=fr'$C_\alpha(X_{{i}}, Y_{{i}}^{{R}})$')
        from matplotlib.lines import Line2D

        legend_Cx = Line2D(
        [0], [0],
        color="black",
        linestyle="--",
        linewidth=1.5,
        label=fr"$C_\alpha(X_{{i}})$"
        )

        legend_Cxy = Line2D(
        [0], [0],
        color="black",
        linestyle="-",
        linewidth=1.5,
        label=fr"$C_\alpha(X_{{i}}, Y_{{i}}^{{R}})$"
        )


        ax.set_xlabel(r'$Y^1$', fontsize=24)
        ax.set_ylabel(r'$Y^2$', fontsize=24)

        plt.xticks([])        
        plt.yticks([])

        leg = ax.legend(fontsize=26, loc='best', ncols=1, handles=[legend_Cx, legend_Cxy])
        # ax.set_xlim(-8, 9)
        # ax.set_ylim(-4, 10)
        leg.set_zorder(2)

        # ax.plot([3.25, 3.25], [-3.3, -3.0], color="black", zorder=3)
        # ax.plot([4.6, 4.6], [-3.3, -3.0], color="black", zorder=3)
                
        plt.tight_layout()

        plt.savefig(f"../figs/revealed_{pert}_{seed}_level_sets_{coverage_emp[0]:.2f}.png", dpi = 300, bbox_inches='tight')
        plt.savefig(f"../figs/revealed_{pert}_{seed}_level_sets_{coverage_emp[0]:.2f}.pdf", dpi = 300, bbox_inches='tight')

        plt.show()

        plt.close()
# Out:
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/plot_data.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:67: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:68: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/plot_data.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:67: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:68: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/plot_data.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:67: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:68: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('viridis', 5)
# /Users/sbraun/Desktop/Gaussian_Conformal_Prediction_V2/experiments/code/plot_data.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:67: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[:, 0], y_specific[:, 1], label=None, c = color_map(i), alpha = 0.2)
# /var/folders/z9/c18gf3b53l57gx2mb36lp9vnx5h51x/T/ipykernel_23890/232044767.py:68: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(y_specific[0, 0], y_specific[0, 1], label=None, c = color_map(i), edgecolors='black', zorder=10)
